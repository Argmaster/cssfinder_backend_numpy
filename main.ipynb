# %%
import numpy as np

# %%
matrix = [
    [0.11875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0.11875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.11875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.01875+0.0j, 0000.0+0.0j, ],
    [0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0000.0+0.0j, 0.11875+0.0j, ],
]

# %%
result = [[0 for _ in range(len(matrix))] for _ in range(len(matrix))]

for i in range(len(matrix)):
    for k in range(len(matrix)):
        result[i][i] += matrix[i][k] * matrix[k][i]

print(np.array(result).trace())
# Out:
# (0.06625+0j)
